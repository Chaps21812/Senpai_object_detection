# %%
import pandas as pd
import Astrometry_tools_EOS as EOS

# %%
# !ls -la ./efs/bjs/
# Out:
# total 812
# drwxrwxrwx 1 david-chaparro david-chaparro    512 Feb 12 14:24 .
# drwxrwxrwx 1 david-chaparro david-chaparro    512 Feb 12 14:24 ..
# drwxrwxrwx 1 david-chaparro david-chaparro    512 Feb 12  2025 annotations
# drwxrwxrwx 1 david-chaparro david-chaparro    512 Feb 12  2025 calsats-with-ephemerides
# -rwxrwxrwx 1 david-chaparro david-chaparro  44836 Feb 12 14:24 catalog-updates.txt
# drwxrwxrwx 1 david-chaparro david-chaparro    512 Feb 12  2025 evaluation-data
# -rwxrwxrwx 1 david-chaparro david-chaparro 786432 Feb 12  2025 fits_with_sp3_ra_dec_v4-clean-2025-01-29.csv

# %%
df = pd.read_csv('./efs/bjs/fits_with_sp3_ra_dec_v4-clean-2025-01-29.csv')

# %%
df.head()
# Out:
#    BITPIX  NAXIS  NAXIS1  NAXIS2  BSCALE  BZERO                    OBSERVER  \
# 0      16      2    2394    1595       1  32768  ATIK APX60 SN:1422313-0224
# 1      16      2    2394    1595       1  32768  ATIK APX60 SN:1422313-0224
# 2      16      2    2394    1595       1  32768  ATIK APX60 SN:1422313-0224
# 3      16      2    2394    1595       1  32768  ATIK APX60 SN:1422313-0224
# 4      16      2    2394    1595       1  32768  ATIK APX60 SN:1422313-0224
#
#    EXPTIME  COLORCCD  DISPINCR  ...  READOUTM  CDS  SITEALT  \
# 0        1         0         1  ...       NaN  NaN   0.1038
# 1        1         0         1  ...       NaN  NaN   0.1038
# 2        1         0         1  ...       NaN  NaN   0.1038
# 3        1         0         1  ...       NaN  NaN   0.1038
# 4        1         0         1  ...       NaN  NaN   0.1038
#
#                        DATE-OBS-MID  satellite_sp3_id  \
# 0  2024-06-26 06:50:03.177000+00:00               G20
# ...

# %%
print(df.columns)
# Out:
# Index(['BITPIX', 'NAXIS', 'NAXIS1', 'NAXIS2', 'BSCALE', 'BZERO', 'OBSERVER',
#        'EXPTIME', 'COLORCCD', 'DISPINCR', 'PICTTYPE', 'XBINNING', 'YBINNING',
#        'CCD-TEMP', 'SET-TEMP', 'SITELAT', 'SITELONG', 'LST', 'CENTAZ',
#        'CENTALT', 'AIRMASS', 'TELEHA', 'TELTKRA', 'TELTKDEC', 'OBJCTRA',
#        'OBJCTDEC', 'OBJECT', 'XPIXSZ', 'YPIXSZ', 'DATE-OBS', 'LOCALTIM',
#        'TRKMODE', 'SENID', 'CLASSIF', 'IMGSETID', 'SEQID', 'SEQCNT',
#        'filename', 'fits_path', 'READOUTM', 'CDS', 'SITEALT', 'DATE-OBS-MID',
#        'satellite_sp3_id', 'satellite_sp3_path', 'true_ra', 'true_dec',
#        'apparent_ra', 'apparent_dec'],
#       dtype='object')

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14210 entries, 0 to 14209
# Data columns (total 49 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   BITPIX              14210 non-null  int64
#  1   NAXIS               14210 non-null  int64
#  2   NAXIS1              14210 non-null  int64
#  3   NAXIS2              14210 non-null  int64
#  4   BSCALE              14210 non-null  int64
#  5   BZERO               14210 non-null  int64
#  6   OBSERVER            14210 non-null  object
#  7   EXPTIME             14210 non-null  int64
#  8   COLORCCD            14210 non-null  int64
#  9   DISPINCR            14210 non-null  int64
#  10  PICTTYPE            14210 non-null  int64
#  11  XBINNING            14210 non-null  int64
#  12  YBINNING            14210 non-null  int64
#  13  CCD-TEMP            14210 non-null  float64
#  14  SET-TEMP            14210 non-null  int64
# ...

# %%
df.apply()

# %%
EOS.view_fits
